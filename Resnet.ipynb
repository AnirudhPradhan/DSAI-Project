# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import matplotlib.pylab as plt
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
train_data_dir = "/content/drive/MyDrive/Brain Tumor Dataset/Brain Tumor/Training"
test_data_dir = "/content/drive/MyDrive/Brain Tumor Dataset/Brain Tumor/Testing"

# %%
image_size = (224, 224)
batch_size = 32

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)
train_generator = train_datagen.flow_from_directory(
    directory=train_data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='sparse',
    subset='training',
    shuffle=True
)
# Out:
# Found 4624 images belonging to 4 classes.

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)
validation_generator = validation_datagen.flow_from_directory(
    directory=train_data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',
    shuffle=False
)
# Out:
# Found 1155 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 1311 images belonging to 4 classes.

# %%
resnet_model = keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3),
)

for layer in resnet_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import tensorflow as tf

model = tf.keras.Sequential([
  resnet_model,
  tf.keras.layers.GlobalMaxPooling2D(),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(4, activation='softmax')
])
model.build(input_shape=(None, 224, 224, 3))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling2d                 │ (None, 2048)                │               0 │
# │ (GlobalMaxPooling2D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,145,668 (92.11 MB)
#  Trainable params: 557,956 (2.13 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1283s 9s/step - accuracy: 0.4122 - loss: 6.4944 - val_accuracy: 0.5550 - val_loss: 1.0447
# Epoch 2/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 523ms/step - accuracy: 0.6075 - loss: 0.9050 - val_accuracy: 0.6450 - val_loss: 1.0578
# Epoch 3/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 525ms/step - accuracy: 0.6411 - loss: 0.8305 - val_accuracy: 0.6537 - val_loss: 0.8468
# Epoch 4/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 555ms/step - accuracy: 0.6777 - loss: 0.7652 - val_accuracy: 0.6537 - val_loss: 1.0049
# Epoch 5/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 77s 529ms/step - accuracy: 0.6946 - loss: 0.7116 - val_accuracy: 0.6693 - val_loss: 0.8368
# Epoch 6/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 81s 558ms/step - accuracy: 0.6740 - loss: 0.7522 - val_accuracy: 0.6649 - val_loss: 0.9592
# Epoch 7/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 522ms/step - accuracy: 0.6757 - loss: 0.7682 - val_accuracy: 0.6416 - val_loss: 0.9853
# Epoch 8/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 75s 515ms/step - accuracy: 0.7042 - loss: 0.7238 - val_accuracy: 0.6476 - val_loss: 0.8502
# Epoch 9/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 88s 555ms/step - accuracy: 0.7220 - loss: 0.6773 - val_accuracy: 0.6779 - val_loss: 0.9212
# Epoch 10/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 77s 528ms/step - accuracy: 0.6829 - loss: 0.7300 - val_accuracy: 0.7004 - val_loss: 0.8470
# Epoch 11/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 521ms/step - accuracy: 0.7320 - loss: 0.6503 - val_accuracy: 0.6494 - val_loss: 0.9724
# Epoch 12/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 550ms/step - accuracy: 0.7294 - loss: 0.6540 - val_accuracy: 0.6208 - val_loss: 1.1567
# Epoch 13/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 77s 530ms/step - accuracy: 0.7227 - loss: 0.6606 - val_accuracy: 0.6303 - val_loss: 0.9349
# Epoch 14/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 554ms/step - accuracy: 0.7294 - loss: 0.6217 - val_accuracy: 0.6987 - val_loss: 0.8778
# Epoch 15/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 549ms/step - accuracy: 0.7205 - loss: 0.6541 - val_accuracy: 0.6892 - val_loss: 0.7801
# Epoch 16/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━
50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 523ms/step - accuracy: 0.7741 - loss: 0.5496 - val_accuracy: 0.6814 - val_loss: 0.8145
# Epoch 42/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 552ms/step - accuracy: 0.7656 - loss: 0.5724 - val_accuracy: 0.7177 - val_loss: 0.7761
# Epoch 43/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 555ms/step - accuracy: 0.7722 - loss: 0.5472 - val_accuracy: 0.6641 - val_loss: 0.9311
# Epoch 44/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 75s 516ms/step - accuracy: 0.7638 - loss: 0.5858 - val_accuracy: 0.7030 - val_loss: 0.8598
# Epoch 45/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 553ms/step - accuracy: 0.7632 - loss: 0.6122 - val_accuracy: 0.6944 - val_loss: 0.8349
# Epoch 46/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 526ms/step - accuracy: 0.7540 - loss: 0.5837 - val_accuracy: 0.7108 - val_loss: 0.9102
# Epoch 47/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 77s 528ms/step - accuracy: 0.7754 - loss: 0.5300 - val_accuracy: 0.7238 - val_loss: 0.8634
# Epoch 48/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 81s 519ms/step - accuracy: 0.7734 - loss: 0.5531 - val_accuracy: 0.7446 - val_loss: 0.8227
# Epoch 49/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 80s 554ms/step - accuracy: 0.7733 - loss: 0.5494 - val_accuracy: 0.7273 - val_loss: 0.7834
# Epoch 50/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 76s 525ms/step - accuracy: 0.7725 - loss: 0.5401 - val_accuracy: 0.7273 - val_loss: 0.9290

# %%
model.save('my_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_acc}')
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 421s 11s/step - accuracy: 0.6435 - loss: 1.0984
# Test Loss: 0.8004621267318726
# Test Accuracy: 0.7414187788963318

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print("Test Accuracy:", test_accuracy)

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_labels = test_generator.classes

confusion_matrix = tf.math.confusion_matrix(true_labels, predicted_classes)
print("Confusion Matrix:")
print(confusion_matrix)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.6435 - loss: 1.0984
# Test Accuracy: 0.7414187788963318
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 14s 247ms/step
# Confusion Matrix:
# tf.Tensor(
# [[204  39  11  46]
#  [ 51  94 102  59]
#  [  6   1 393   5]
#  [ 12   1   6 281]], shape=(4, 4), dtype=int32)

# %%
import matplotlib.pyplot as plt

def plot_metrics(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.show()

plot_metrics(history)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = test_generator.classes
y_pred_prob = model.predict(test_generator)

y_true_one_hot = label_binarize(y_true, classes=[0, 1, 2, 3])

fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_true_one_hot.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_one_hot[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_true_one_hot.ravel(), y_pred_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step

# %%
plt.figure(figsize=(12, 8))

plt.plot(fpr["micro"], tpr["micro"],
         label='Micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='Macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in enumerate(colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves for Multi-Class Classification')
plt.legend(loc="lower right")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


y_true = test_generator.classes  # Actual numerical labels

# Get predicted labels
y_pred = np.argmax(model.predict(test_generator), axis=1)

# Class names (from test_generator)
class_names = list(test_generator.class_indices.keys())  # Extract class names

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)  # Remove labels=class_names

# Plot confusion matrix
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.75      0.68      0.71       300
#   meningioma       0.70      0.31      0.43       306
#      notumor       0.77      0.97      0.86       405
#    pituitary       0.72      0.94      0.81       300
#
#     accuracy                           0.74      1311
#    macro avg       0.73      0.72      0.70      1311
# weighted avg       0.74      0.74      0.71      1311
